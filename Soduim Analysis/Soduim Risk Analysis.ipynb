# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
survivors = pd.read_csv("survivors.csv")
mortality = pd.read_csv("deaths.csv")

# %%
survivors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3432 entries, 0 to 3431
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                3432 non-null   int64
#  1   age                       3432 non-null   float64
#  2   anaemia                   3432 non-null   int64
#  3   creatinine_phosphokinase  3432 non-null   int64
#  4   diabetes                  3432 non-null   int64
#  5   ejection_fraction         3432 non-null   int64
#  6   high_blood_pressure       3432 non-null   int64
#  7   platelets                 3432 non-null   float64
#  8   serum_creatinine          3432 non-null   float64
#  9   serum_sodium              3432 non-null   int64
#  10  sex                       3432 non-null   int64
#  11  smoking                   3432 non-null   int64
#  12  time                      3432 non-null   int64
#  13  DEATH_EVENT               3432 non-null   int64
# ...

# %%
male = pd.read_csv("Male.csv")
female = pd.read_csv("Female.csv")

# %%
maleSurvivor = pd.read_csv("maleSurvivor.csv")
femaleSurvivor = pd.read_csv("femaleSurvivors.csv")
maleMortality = pd.read_csv("MaleDeaths.csv")
femaleMortality = pd.read_csv("femaleDeath.csv")

# %%
survivors["Soduim Risk"] = pd.cut(x=survivors["serum_sodium"], bins = [0,135,137,141,survivors["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
survivors["Soduim Risk"]
# Out:
# 0       Increased Risk
# 1         Highest Risk
# 2             Low Risk
# 3         Highest Risk
# 4         Highest Risk
#              ...
# 3427    Increased Risk
# 3428           No Risk
# 3429      Highest Risk
# 3430           No Risk
# 3431          Low Risk
# Name: Soduim Risk, Length: 3432, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
mortality["Soduim Risk"] = pd.cut(x=mortality["serum_sodium"], bins = [0,135,137,141,mortality["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
mortality["Soduim Risk"]
# Out:
# 0       Highest Risk
# 1           Low Risk
# 2           Low Risk
# 3       Highest Risk
# 4           Low Risk
#             ...
# 1563    Highest Risk
# 1564    Highest Risk
# 1565    Highest Risk
# 1566        Low Risk
# 1567    Highest Risk
# Name: Soduim Risk, Length: 1568, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
male["Soduim Risk"] = pd.cut(x=male["serum_sodium"], bins = [0,135,137,141,male["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
male["Soduim Risk"]
# Out:
# 0       Increased Risk
# 1         Highest Risk
# 2         Highest Risk
# 3         Highest Risk
# 4         Highest Risk
#              ...
# 3223    Increased Risk
# 3224      Highest Risk
# 3225      Highest Risk
# 3226           No Risk
# 3227    Increased Risk
# Name: Soduim Risk, Length: 3228, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
female["Soduim Risk"] = pd.cut(x=female["serum_sodium"], bins = [0,135,137,141,female["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
female["Soduim Risk"]
# Out:
# 0             Low Risk
# 1              No Risk
# 2             Low Risk
# 3       Increased Risk
# 4             Low Risk
#              ...
# 1767      Highest Risk
# 1768           No Risk
# 1769          Low Risk
# 1770      Highest Risk
# 1771          Low Risk
# Name: Soduim Risk, Length: 1772, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
maleSurvivor["Soduim Risk"] = pd.cut(x=maleSurvivor["serum_sodium"], bins = [0,135,137,141,maleSurvivor["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
maleSurvivor["Soduim Risk"]
# Out:
# 0       Increased Risk
# 1         Highest Risk
# 2         Highest Risk
# 3         Highest Risk
# 4         Highest Risk
#              ...
# 2149      Highest Risk
# 2150    Increased Risk
# 2151      Highest Risk
# 2152           No Risk
# 2153    Increased Risk
# Name: Soduim Risk, Length: 2154, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
femaleSurvivor["Soduim Risk"] = pd.cut(x=femaleSurvivor["serum_sodium"], bins = [0,135,137,141,femaleSurvivor["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
femaleSurvivor["Soduim Risk"]
# Out:
# 0             Low Risk
# 1              No Risk
# 2             Low Risk
# 3       Increased Risk
# 4       Increased Risk
#              ...
# 1273    Increased Risk
# 1274           No Risk
# 1275      Highest Risk
# 1276           No Risk
# 1277          Low Risk
# Name: Soduim Risk, Length: 1278, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
maleMortality["Soduim Risk"] = pd.cut(x=maleMortality["serum_sodium"], bins = [0,135,137,141,maleMortality["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
maleMortality["Soduim Risk"]
# Out:
# 0         Highest Risk
# 1             Low Risk
# 2         Highest Risk
# 3             Low Risk
# 4       Increased Risk
#              ...
# 1069    Increased Risk
# 1070      Highest Risk
# 1071          Low Risk
# 1072      Highest Risk
# 1073      Highest Risk
# Name: Soduim Risk, Length: 1074, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
femaleMortality["Soduim Risk"] = pd.cut(x=femaleMortality["serum_sodium"], bins = [0,135,137,141,femaleMortality["serum_sodium"].max()],labels = ["Highest Risk","Increased Risk","Low Risk","No Risk"])
femaleMortality["Soduim Risk"]
# Out:
# 0            Low Risk
# 1            Low Risk
# 2        Highest Risk
# 3             No Risk
# 4            Low Risk
#             ...
# 489    Increased Risk
# 490      Highest Risk
# 491      Highest Risk
# 492          Low Risk
# 493      Highest Risk
# Name: Soduim Risk, Length: 494, dtype: category
# Categories (4, object): ['Highest Risk' < 'Increased Risk' < 'Low Risk' < 'No Risk']

# %%
counts = maleSurvivor["Soduim Risk"].value_counts()
fig, ax = plt.subplots()
plt.bar(counts.index, counts)
ax.set_title("Count plot of Soduim Risk for Male survivors")
plt.xlabel("Soduim Risk")
ax.set_ylim(0, len(male))
plt.ylabel("count")
plt.grid()
plt.show()

# %%
counts = maleMortality["Soduim Risk"].value_counts()
fig, ax = plt.subplots()
plt.bar(counts.index, counts)
ax.set_title("Count plot of Soduim Risk for Male mortality")
plt.xlabel("Soduim Risk")
ax.set_ylim(0, len(male))
plt.ylabel("count")
plt.grid()
plt.show()

# %%
counts = femaleSurvivor["Soduim Risk"].value_counts()
fig, ax = plt.subplots()
plt.bar(counts.index, counts, color = "pink")
ax.set_title("Count plot of Soduim Risk for Female survivors")
plt.xlabel("Soduim Risk")
ax.set_ylim(0, len(female))
plt.ylabel("count")
plt.grid()
plt.show()

# %%
counts = femaleMortality["Soduim Risk"].value_counts()
fig, ax = plt.subplots()
plt.bar(counts.index, counts, color = "pink")
ax.set_title("Count plot of Soduim Risk for Female mortality")
plt.xlabel("Soduim Risk")
ax.set_ylim(0, len(female))
plt.ylabel("count")
plt.grid()
plt.show()

# %%
counts = survivors.groupby(['Soduim Risk', 'sex']).size().unstack(fill_value=0)
index = range(len(counts))
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = plt.bar(index, counts[1], bar_width, label='Male', color='blue')
bars2 = plt.bar([i + bar_width for i in index], counts[0], bar_width, label='Female', color='pink')
ax.set_title = ("Count Plot of Soduim Risk Levels for survivors")
plt.xlabel("Soduim Risk Levels")
ax.set_ylim(0,len(survivors))
plt.ylabel("Count")

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    max_height = max(bar1.get_height(), bar2.get_height())
    soduim_level = counts.index[i]
    plt.text(bar1.get_x() + bar1.get_width() / 2, -0.5, soduim_level, ha='center', va='center', weight = "bold", color = "green")
    #plt.text(bar2.get_x() + bar2.get_width() / 2, -0.5, soduim_level, ha='center', va='center', rotation = 90)

plt.grid()
plt.show()

# %%
counts = mortality.groupby(['Soduim Risk', 'sex']).size().unstack(fill_value=0)
index = range(len(counts))
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = plt.bar(index, counts[1], bar_width, label='Male', color='blue')
bars2 = plt.bar([i + bar_width for i in index], counts[0], bar_width, label='Female', color='pink')
ax.set_title = ("Count Plot of Soduim Risk Levels for mortality")
plt.xlabel("Soduim Risk Levels")
ax.set_ylim(0,len(mortality))
plt.ylabel("Count")

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    max_height = max(bar1.get_height(), bar2.get_height())
    soduim_level = counts.index[i]
    plt.text(bar1.get_x() + bar1.get_width() / 2, -0.5, soduim_level, ha='center', va='center', weight = "bold", color = "green")
    #plt.text(bar2.get_x() + bar2.get_width() / 2, -0.5, soduim_level, ha='center', va='center', rotation = 90)

plt.grid()
plt.show()

# %%
counts = male.groupby(['Soduim Risk', 'DEATH_EVENT']).size().unstack(fill_value=0)
index = range(len(counts))
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = plt.bar(index, counts[1], bar_width, label='Survivor', color='Green')
bars2 = plt.bar([i + bar_width for i in index], counts[0], bar_width, label='Death', color='RED')
ax.set_title = ("Count Plot of Soduim Risk Levels for Males")
plt.xlabel("Soduim Risk Levels")
ax.set_ylim(0,len(male))
plt.ylabel("Count")

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    max_height = max(bar1.get_height(), bar2.get_height())
    soduim_level = counts.index[i]
    plt.text(bar1.get_x() + bar1.get_width() / 2, -0.5, soduim_level, ha='center', va='center', weight = "bold", color = "blue")
    #plt.text(bar2.get_x() + bar2.get_width() / 2, -0.5, soduim_level, ha='center', va='center', rotation = 90)

plt.grid()
plt.show()

# %%
counts = female.groupby(['Soduim Risk', 'DEATH_EVENT']).size().unstack(fill_value=0)
index = range(len(counts))
bar_width = 0.35
fig, ax = plt.subplots()
bars1 = plt.bar(index, counts[1], bar_width, label='Survivor', color='Green')
bars2 = plt.bar([i + bar_width for i in index], counts[0], bar_width, label='Death', color='RED')
ax.set_title = ("Count Plot of Soduim Risk Levels for females")
plt.xlabel("Soduim Risk Levels")
ax.set_ylim(0,len(female))
ax.set_xticklabels([])

plt.ylabel("Count")

for bar in bars1:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for bar in bars2:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, int(yval), ha='center', va='bottom')

for i, (bar1, bar2) in enumerate(zip(bars1, bars2)):
    max_height = max(bar1.get_height(), bar2.get_height())
    soduim_level = counts.index[i]
    plt.text(bar1.get_x() + bar1.get_width() / 2, -2, soduim_level, ha='center', va='center', weight = "bold", color = "blue")
    #plt.text(bar2.get_x() + bar2.get_width() / 2, max_height, soduim_level, ha='center', va='center')

plt.grid()
plt.show()
