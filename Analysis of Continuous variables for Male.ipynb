# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Analysis of Male Survivors

# %%
males = pd.read_csv("MaleSurvivor.csv")

# %%
males
# Out:
#       Unnamed: 0.1  Unnamed: 0   age  anaemia  creatinine_phosphokinase  \
# 0                0           0  55.0        0                       748
# 1                1           1  65.0        0                        56
# 2                2           3  60.0        1                       754
# 3                4           5  70.0        0                       232
# 4                5           8  50.0        0                       482
# ...            ...         ...   ...      ...                       ...
# 2149          3220        4981  44.0        0                       582
# 2150          3223        4984  55.0        0                       748
# 2151          3224        4988  55.0        0                        60
# 2152          3226        4990  75.0        0                       119
# 2153          3227        4991  53.0        1                       582
#
#       diabetes  ejection_fraction  high_blood_pressure  platelets  \
# ...

# %%
males.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0          age      anaemia  \
# count   2154.000000  2154.000000  2154.000000  2154.000000
# mean    1616.789694  2545.473538    58.626122     0.438254
# std      942.350438  1454.334529    10.383601     0.496288
# min        0.000000     0.000000    40.000000     0.000000
# 25%      797.500000  1290.750000    51.000000     0.000000
# 50%     1615.000000  2571.000000    60.000000     0.000000
# 75%     2441.750000  3819.250000    65.000000     1.000000
# max     3227.000000  4991.000000    90.000000     1.000000
#
#        creatinine_phosphokinase     diabetes  ejection_fraction  \
# count               2154.000000  2154.000000        2154.000000
# mean                 569.764624     0.403435          39.745590
# std                  825.447456     0.490701          10.454746
# min                   25.000000     0.000000          17.000000
# 25%                  118.000000     0.000000          35.000000
# ...

# %% [markdown]
# ## Analysis of CPK

# %%
max(males["creatinine_phosphokinase"])
# Out:
# 7861

# %%
males["CPK Levels"] = pd.cut(x=males["creatinine_phosphokinase"],bins = [10,120,7861], labels=["normal","high"])

# %%
males["CPK Levels"]
# Out:
# 0         high
# 1       normal
# 2         high
# 3         high
# 4         high
#          ...
# 2149      high
# 2150      high
# 2151    normal
# 2152    normal
# 2153      high
# Name: CPK Levels, Length: 2154, dtype: category
# Categories (2, object): ['normal' < 'high']

# %%
print(males["CPK Levels"].value_counts())
# Out:
# high      1576
# normal     578
# Name: CPK Levels, dtype: int64

# %%
counts = males['CPK Levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of CPK Levels")
plt.xlabel("CPK Levels")
plt.ylabel("Count")
plt.show()

# %%
males["ejection fraction levels"] = pd.cut(x=males["ejection_fraction"],bins = [0,30,40,51,72], labels=["severely abnormal","moderately abnormal","mildly abnormal","normal"])

# %%
males["ejection fraction levels"]
# Out:
# 0           mildly abnormal
# 1         severely abnormal
# 2       moderately abnormal
# 3         severely abnormal
# 4         severely abnormal
#                ...
# 2149      severely abnormal
# 2150        mildly abnormal
# 2151    moderately abnormal
# 2152        mildly abnormal
# 2153        mildly abnormal
# Name: ejection fraction levels, Length: 2154, dtype: category
# Categories (4, object): ['severely abnormal' < 'moderately abnormal' < 'mildly abnormal' < 'normal']

# %%
counts = males['ejection fraction levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of ejection fraction levels")
plt.xlabel("ejection fraction levels")
plt.ylabel("Count")
plt.show()

# %%
max(males["serum_creatinine"])
# Out:
# 6.1

# %%
males["serum creatinine levels"] = pd.cut(x=males["serum_creatinine"],bins = [0,0.7,1.3,6.1], labels=["low","normal","abnormal"])

# %%
males["serum creatinine levels"]
# Out:
# 0         normal
# 1       abnormal
# 2         normal
# 3         normal
# 4         normal
#           ...
# 2149    abnormal
# 2150      normal
# 2151      normal
# 2152      normal
# 2153      normal
# Name: serum creatinine levels, Length: 2154, dtype: category
# Categories (3, object): ['low' < 'normal' < 'abnormal']

# %%
counts = males['serum creatinine levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum creatinine levels")
plt.xlabel("serum creatinine levels")
plt.ylabel("Count")
plt.show()

# %%
max(males["serum_sodium"])
# Out:
# 148

# %%
males["serum sodium levels"] = pd.cut(x=males["serum_sodium"],bins = [0,135,145,148], labels=["low","normal","abnormal"])

# %%
males["serum sodium levels"]
# Out:
# 0         normal
# 1            low
# 2            low
# 3            low
# 4            low
#           ...
# 2149         low
# 2150      normal
# 2151         low
# 2152    abnormal
# 2153      normal
# Name: serum sodium levels, Length: 2154, dtype: category
# Categories (3, object): ['low' < 'normal' < 'abnormal']

# %%
counts = males['serum sodium levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum sodium levels")
plt.xlabel("serum sodium levels")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # Analysis of Male Mortality

# %%
malemortality = pd.read_csv("MaleDeaths.csv")

# %%
malemortality
# Out:
#       Unnamed: 0.1  Unnamed: 0   age  anaemia  creatinine_phosphokinase  \
# 0                3           4  95.0        1                       582
# 1                9          15  60.0        1                        34
# 2               10          16  75.0        0                        99
# 3               12          19  60.0        1                        47
# 4               14          22  50.0        1                       111
# ...            ...         ...   ...      ...                       ...
# 1069          3212        4968  50.0        1                       111
# 1070          3219        4980  60.0        1                       260
# 1071          3221        4982  62.0        0                       231
# 1072          3222        4983  65.0        1                       258
# 1073          3225        4989  60.0        1                       154
#
#       diabetes  ejection_fraction  high_blood_pressure  platelets  \
# ...

# %%
malemortality.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0          age      anaemia  \
# count   1074.000000  1074.000000  1074.000000  1074.000000
# mean    1606.902235  2531.504655    65.513661     0.456238
# std      911.247389  1405.832274    13.213144     0.498313
# min        3.000000     4.000000    42.000000     0.000000
# 25%      838.250000  1353.250000    55.750000     0.000000
# 50%     1611.500000  2566.500000    65.000000     0.000000
# 75%     2368.500000  3710.500000    75.000000     1.000000
# max     3225.000000  4989.000000    95.000000     1.000000
#
#        creatinine_phosphokinase     diabetes  ejection_fraction  \
# count               1074.000000  1074.000000        1074.000000
# mean                 772.387337     0.341713          30.808194
# std                 1486.776467     0.474505          10.160982
# min                   23.000000     0.000000          14.000000
# 25%                  129.000000     0.000000          20.000000
# ...

# %%
malemortality["creatinine_phosphokinase"]
# Out:
# 0       582
# 1        34
# 2        99
# 3        47
# 4       111
#        ...
# 1069    111
# 1070    260
# 1071    231
# 1072    258
# 1073    154
# Name: creatinine_phosphokinase, Length: 1074, dtype: int64

# %%
malemortality["CPK Levels"] = pd.cut(x=malemortality["creatinine_phosphokinase"],bins = [10,120,7861], labels=["normal","high"])

# %%
malemortality["CPK Levels"]
# Out:
# 0         high
# 1       normal
# 2       normal
# 3       normal
# 4       normal
#          ...
# 1069    normal
# 1070      high
# 1071      high
# 1072      high
# 1073      high
# Name: CPK Levels, Length: 1074, dtype: category
# Categories (2, object): ['normal' < 'high']

# %%
counts = malemortality['CPK Levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of CPK Levels")
plt.xlabel("CPK Levels")
plt.ylabel("Count")
plt.show()

# %%
malemortality["ejection_fraction"]
# Out:
# 0       30
# 1       20
# 2       20
# 3       20
# 4       20
#         ..
# 1069    20
# 1070    38
# 1071    25
# 1072    25
# 1073    25
# Name: ejection_fraction, Length: 1074, dtype: int64

# %%
malemortality["ejection fraction levels"] = pd.cut(x=malemortality["ejection_fraction"],bins = [0,30,40,51,72], labels=["severely abnormal","moderately abnormal","mildly abnormal","normal"])

# %%
malemortality["ejection fraction levels"]
# Out:
# 0         severely abnormal
# 1         severely abnormal
# 2         severely abnormal
# 3         severely abnormal
# 4         severely abnormal
#                ...
# 1069      severely abnormal
# 1070    moderately abnormal
# 1071      severely abnormal
# 1072      severely abnormal
# 1073      severely abnormal
# Name: ejection fraction levels, Length: 1074, dtype: category
# Categories (4, object): ['severely abnormal' < 'moderately abnormal' < 'mildly abnormal' < 'normal']

# %%
counts = malemortality['ejection fraction levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of ejection fraction levels")
plt.xlabel("ejection fraction levels")
plt.ylabel("Count")
plt.show()

# %%
malemortality["serum creatinine levels"] = pd.cut(x=malemortality["serum_creatinine"],bins = [0,0.7,1.3,6.1], labels=["low","normal","abnormal"])

# %%
malemortality["serum creatinine levels"]
# Out:
# 0       abnormal
# 1            low
# 2       abnormal
# 3            low
# 4       abnormal
#           ...
# 1069    abnormal
# 1070    abnormal
# 1071      normal
# 1072    abnormal
# 1073    abnormal
# Name: serum creatinine levels, Length: 1074, dtype: category
# Categories (3, object): ['low' < 'normal' < 'abnormal']

# %%
counts = malemortality['serum creatinine levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum creatinine levels")
plt.xlabel("serum creatinine levels")
plt.ylabel("Count")
plt.show()

# %%
malemortality["serum sodium levels"] = pd.cut(x=malemortality["serum_sodium"],bins = [0,135,145,148], labels=["low","normal","abnormal"])

# %%
malemortality["serum sodium levels"]
# Out:
# 0          low
# 1       normal
# 2          low
# 3       normal
# 4       normal
#          ...
# 1069    normal
# 1070       low
# 1071    normal
# 1072       low
# 1073       low
# Name: serum sodium levels, Length: 1074, dtype: category
# Categories (3, object): ['low' < 'normal' < 'abnormal']

# %%
counts = malemortality['serum sodium levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum sodium levels")
plt.xlabel("serum sodium levels")
plt.ylabel("Count")
plt.show()
