# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Analysis of Female Survivors

# %%
femaleSurvivors = pd.read_csv("femaleSurvivors.csv")

# %%
femaleSurvivors
# Out:
#       Unnamed: 0.1  Unnamed: 0     age  anaemia  creatinine_phosphokinase  \
# 0                0           2  45.000        0                       582
# 1                1           6  63.000        1                       122
# 2                2           7  70.000        1                       171
# 3                3          10  60.667        1                       151
# 4                5          14  65.000        0                       335
# ...            ...         ...     ...      ...                       ...
# 1273          1764        4992  65.000        1                       335
# 1274          1765        4993  60.000        1                       582
# 1275          1767        4995  45.000        0                       582
# 1276          1768        4996  60.000        1                       582
# 1277          1771        4999  40.000        0                       244
#
#       diabetes  ejection_fraction  high_blood_pressure  platelets  \
# ...

# %%
femaleSurvivors.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0          age      anaemia  \
# count   1278.000000  1278.000000  1278.000000  1278.000000
# mean     873.847418  2391.131455    57.795261     0.485915
# std      513.113526  1454.328043    10.435081     0.499997
# min        0.000000     2.000000    40.000000     0.000000
# 25%      424.250000  1089.500000    50.000000     0.000000
# 50%      861.500000  2309.500000    58.000000     0.000000
# 75%     1322.750000  3666.500000    65.000000     1.000000
# max     1771.000000  4999.000000    90.000000     1.000000
#
#        creatinine_phosphokinase     diabetes  ejection_fraction  \
# count               1278.000000  1278.000000        1278.000000
# mean                 474.107981     0.510172          40.462441
# std                  599.839808     0.500092          10.721056
# min                   25.000000     0.000000          20.000000
# 25%                  101.000000     0.000000          35.000000
# ...

# %%
femaleSurvivors["CPK Levels"] = pd.cut(x=femaleSurvivors["creatinine_phosphokinase"],bins = [10,120,7861], labels=["normal","high"])

# %%
femaleSurvivors["ejection fraction levels"] = pd.cut(x=femaleSurvivors["ejection_fraction"],bins = [0,30,40,51,72], labels=["severely abnormal","moderately abnormal","mildly abnormal","normal"])

# %%
femaleSurvivors["serum creatinine levels"] = pd.cut(x=femaleSurvivors["serum_creatinine"],bins = [0,0.7,1.3,6.1], labels=["low","normal","abnormal"])

# %%
femaleSurvivors["serum sodium levels"] = pd.cut(x=femaleSurvivors["serum_sodium"],bins = [0,135,145,148], labels=["low","normal","abnormal"])

# %%
counts = femaleSurvivors['CPK Levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of CPK Levels")
plt.xlabel("CPK Levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleSurvivors['ejection fraction levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of ejection fraction levels")
plt.xlabel("ejection fraction levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleSurvivors['serum creatinine levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum creatinine levels")
plt.xlabel("serum creatinine levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleSurvivors['serum sodium levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum sodium levels")
plt.xlabel("serum sodium levels")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Analysis for Female Mortality

# %%
femaleMortality = pd.read_csv("femaleDeath.csv")

# %%
femaleMortality
# Out:
#      Unnamed: 0.1  Unnamed: 0   age  anaemia  creatinine_phosphokinase  \
# 0               4          11  72.0        1                       110
# 1               6          18  72.0        1                       110
# 2              12          39  95.0        1                       371
# 3              23          70  60.0        0                      2656
# 4              28          80  95.0        1                       281
# ..            ...         ...   ...      ...                       ...
# 489          1754        4964  70.0        1                       143
# 490          1757        4973  86.0        0                       582
# 491          1766        4994  65.0        1                       160
# 492          1769        4997  95.0        1                       112
# 493          1770        4998  65.0        1                       160
#
#      diabetes  ejection_fraction  high_blood_pressure  platelets  \
# ...

# %%
femaleMortality.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0         age     anaemia  \
# count    494.000000   494.000000  494.000000  494.000000
# mean     915.645749  2509.813765   62.629555    0.641700
# std      507.215265  1438.800622   12.702175    0.479987
# min        4.000000    11.000000   40.000000    0.000000
# 25%      494.000000  1294.500000   50.000000    0.000000
# 50%      937.500000  2513.500000   60.000000    1.000000
# 75%     1334.750000  3700.750000   72.000000    1.000000
# max     1770.000000  4998.000000   95.000000    1.000000
#
#        creatinine_phosphokinase    diabetes  ejection_fraction  \
# count                494.000000  494.000000         494.000000
# mean                 548.736842    0.625506          36.967611
# std                  918.823772    0.484483          14.235165
# min                   47.000000    0.000000          14.000000
# 25%                  131.000000    0.000000          25.000000
# 50%                  250.000000    1.000000          35.000000
# ...

# %%
femaleMortality["CPK Levels"] = pd.cut(x=femaleMortality["creatinine_phosphokinase"],bins = [10,120,7861], labels=["normal","high"])

# %%
femaleMortality["ejection fraction levels"] = pd.cut(x=femaleMortality["ejection_fraction"],bins = [0,30,40,51,72], labels=["severely abnormal","moderately abnormal","mildly abnormal","normal"])

# %%
femaleMortality["serum creatinine levels"] = pd.cut(x=femaleMortality["serum_creatinine"],bins = [0,0.7,1.3,6.1], labels=["low","normal","abnormal"])

# %%
femaleMortality["serum sodium levels"] = pd.cut(x=femaleMortality["serum_sodium"],bins = [0,135,145,148], labels=["low","normal","abnormal"])

# %%
counts = femaleMortality['CPK Levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of CPK Levels")
plt.xlabel("CPK Levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleMortality['ejection fraction levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of ejection fraction levels")
plt.xlabel("ejection fraction levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleMortality['serum creatinine levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum creatinine levels")
plt.xlabel("serum creatinine levels")
plt.ylabel("Count")
plt.show()

# %%
counts = femaleMortality['serum sodium levels'].value_counts()

plt.figure(figsize=(8,6))
plt.bar(counts.index, counts)
plt.title = ("Count Plot of serum sodium levels")
plt.xlabel("serum sodium levels")
plt.ylabel("Count")
plt.show()
